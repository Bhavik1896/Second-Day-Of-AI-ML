# %%
import pandas as pd
from pandas.conftest import axis_1

df = pd.read_csv('/Users/bhavikjain/Desktop/Python_Project/AI ML/First Project/titanic.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.mode()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 0              1       0.0     3.0                    Abbing, Mr. Anthony
# 1              2       NaN     NaN            Abbott, Mr. Rossmore Edward
# 2              3       NaN     NaN       Abbott, Mrs. Stanton (Rosa Hunt)
# 3              4       NaN     NaN                    Abelson, Mr. Samuel
# 4              5       NaN     NaN  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 886          887       NaN     NaN                de Mulder, Mr. Theodore
# 887          888       NaN     NaN              de Pelsmaeker, Mr. Alfons
# 888          889       NaN     NaN              del Carlo, Mr. Sebastiano
# 889          890       NaN     NaN        van Billiard, Mr. Austin Blyler
# 890          891       NaN     NaN            van Melkebeke, Mr. Philemon
#
#       Sex   Age  SibSp  Parch    Ticket  Fare        Cabin Embarked
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.describe(include="all") # by default it is applied on all numerical columns default means df.describe()

# 50% derives the median also called as Q3 or Quater 2
# min represents minimum value
# max represents maimum value
# 25% represents Left side of the distributed graph // or half of the median also called called as Q1 or Quater 1
# 75% represents Right side of the distributed graph // or half of the median also called called as Q3 or Quater 3
# IQR is 75% - 25% then 1.5 * IQR
# value out of range either on left or on right means too grater or too lesser
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# ## EDA With Graphs

# %% [markdown]
# ### Histogram

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(data=df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data=df['Age'])
# sns.boxplot(x='Age', data=df)
# Out:
# <Axes: ylabel='Age'>

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
